# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных,-поиск-ошибок,-предобработка" data-toc-modified-id="Обзор-данных,-поиск-ошибок,-предобработка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных, поиск ошибок, предобработка</a></span><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Проверка-типов-данных" data-toc-modified-id="Проверка-типов-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка типов данных</a></span></li><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Работа с пропусками</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка дубликатов</a></span></li><li><span><a href="#Проверка-аномальных-значений" data-toc-modified-id="Проверка-аномальных-значений-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверка аномальных значений</a></span></li><li><span><a href="#Общий-вывод-по-разделу" data-toc-modified-id="Общий-вывод-по-разделу-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Общий вывод по разделу</a></span></li></ul></li><li><span><a href="#Задание-необходимых-функций" data-toc-modified-id="Задание-необходимых-функций-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задание необходимых функций</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-профилей-пользователей:" data-toc-modified-id="Функция-для-создания-профилей-пользователей:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания профилей пользователей:</a></span></li><li><span><a href="#Функция-для-подсчета-Retention-Rate:" data-toc-modified-id="Функция-для-подсчета-Retention-Rate:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для подсчета Retention Rate:</a></span></li><li><span><a href="#Функция-для-подсчета-конверсии:" data-toc-modified-id="Функция-для-подсчета-конверсии:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для подсчета конверсии:</a></span></li><li><span><a href="#Функция-для-подсчета-LTV-и-ROI" data-toc-modified-id="Функция-для-подсчета-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для подсчета LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-данных" data-toc-modified-id="Функция-для-сглаживания-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания данных</a></span></li><li><span><a href="#Функция-для-построения-графика-Retention-Rate" data-toc-modified-id="Функция-для-построения-графика-Retention-Rate-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для построения графика Retention Rate</a></span></li><li><span><a href="#Функция-для-построения-графика-конверсии" data-toc-modified-id="Функция-для-построения-графика-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для построения графика конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li><li><span><a href="#Общий-вывод-по-разделу" data-toc-modified-id="Общий-вывод-по-разделу-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Общий вывод по разделу</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профиль-пользователей.-Минимальная-и-максимальная-дата-привлечения-пользователей" data-toc-modified-id="Профиль-пользователей.-Минимальная-и-максимальная-дата-привлечения-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профиль пользователей. Минимальная и максимальная дата привлечения пользователей</a></span></li><li><span><a href="#Регион-пользователей.-Доля-платящих-по-региону" data-toc-modified-id="Регион-пользователей.-Доля-платящих-по-региону-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Регион пользователей. Доля платящих по региону</a></span></li><li><span><a href="#Устройства-пользователей.-Доля-платящих-по-устройствам" data-toc-modified-id="Устройства-пользователей.-Доля-платящих-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Устройства пользователей. Доля платящих по устройствам</a></span></li><li><span><a href="#Каналы-привлечения-пользователей.-Доля-платящих-по-каналам" data-toc-modified-id="Каналы-привлечения-пользователей.-Доля-платящих-по-каналам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Каналы привлечения пользователей. Доля платящих по каналам</a></span></li><li><span><a href="#Общий-вывод-по-разделу" data-toc-modified-id="Общий-вывод-по-разделу-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Общий вывод по разделу</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов-на-маркетинг" data-toc-modified-id="Общая-сумма-расходов-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общая сумма расходов на маркетинг</a></span></li><li><span><a href="#Распределение-расходов-по-рекламным-источникам" data-toc-modified-id="Распределение-расходов-по-рекламным-источникам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Распределение расходов по рекламным источникам</a></span></li><li><span><a href="#Визуализация-динамики-изменения-расходов-по-времени" data-toc-modified-id="Визуализация-динамики-изменения-расходов-по-времени-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Визуализация динамики изменения расходов по времени</a></span></li><li><span><a href="#Средняя-стоимость-привлечения-одного-пользователя" data-toc-modified-id="Средняя-стоимость-привлечения-одного-пользователя-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средняя стоимость привлечения одного пользователя</a></span></li><li><span><a href="#Общий-вывод-по-разделу" data-toc-modified-id="Общий-вывод-по-разделу-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Общий вывод по разделу</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI" data-toc-modified-id="Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Графики LTV и ROI, а также динамики LTV, CAC и ROI</a></span></li><li><span><a href="#Конверсия-и-удержание,-динамика-их-изменения" data-toc-modified-id="Конверсия-и-удержание,-динамика-их-изменения-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Конверсия и удержание, динамика их изменения</a></span><ul class="toc-item"><li><span><a href="#Конверсия-и-удержание-с-развибкой-по-устройствам" data-toc-modified-id="Конверсия-и-удержание-с-развибкой-по-устройствам-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Конверсия и удержание с развибкой по устройствам</a></span></li><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-регионам" data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-регионам-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по регионам</a></span></li><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-каналам-привлечения" data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-каналам-привлечения-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по каналам привлечения</a></span></li></ul></li><li><span><a href="#Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-с-разбивкой-по-устройствам" data-toc-modified-id="Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Графики LTV и ROI, а также динамики LTV, CAC и ROI с разбивкой по устройствам</a></span></li><li><span><a href="#Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-с-разбивкой-по-регионам" data-toc-modified-id="Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-с-разбивкой-по-регионам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Графики LTV и ROI, а также динамики LTV, CAC и ROI с разбивкой по регионам</a></span></li><li><span><a href="#Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-с-разбивкой-по-каналам" data-toc-modified-id="Графики-LTV-и-ROI,-а-также-динамики-LTV,-CAC-и-ROI-с-разбивкой-по-каналам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Графики LTV и ROI, а также динамики LTV, CAC и ROI с разбивкой по каналам</a></span></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проверка гипотез</a></span></li><li><span><a href="#Общий-вывод-по-разделу" data-toc-modified-id="Общий-вывод-по-разделу-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Общий вывод по разделу</a></span></li></ul></li><li><span><a href="#Общий-вывод-по-исследованию" data-toc-modified-id="Общий-вывод-по-исследованию-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод по исследованию</a></span></li></ul></div>

# %% [markdown]
# # Аналитика развлекательного приложения Procrastinate Pro+

# %% [markdown]
# **Исходные предпосылки:**\
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
# **Задача исследования:**\
# Разобраться в причинах убытков компании и помочь выйти в плюс.
#
# **Структура данных:**
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# лог сервера с данными об их посещениях,
# выгрузка их покупок за этот период,
# рекламные расходы.
#
# Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта, orders_info_short.csv — информацию о заказах, а costs_info_short.csv — информацию о расходах на рекламу.
#
# Структура visits_info_short.csv:\
# User Id — уникальный идентификатор пользователя,\
# Region — страна пользователя,\
# Device — тип устройства пользователя,\
# Channel — идентификатор источника перехода,\
# Session Start — дата и время начала сессии,\
# Session End — дата и время окончания сессии.
#
# Структура orders_info_short.csv:\
# User Id — уникальный идентификатор пользователя,\
# Event Dt — дата и время покупки,\
# Revenue — сумма заказа.
#
# Структура costs_info_short.csv:\
# dt — дата проведения рекламной кампании,\
# Channel — идентификатор рекламного источника,\
# costs — расходы на эту кампанию.

# %% [markdown]
# **Ход исследования:**\
# О качестве данных информации нет. Перед проведением исследования понадобится обзор данных.
#
# Исследование будет состоять из следующих этапов:
# 1. Обзор данных, поиск ошибок, предобработка;\
#    1.1 Обзор данных;\
#    1.2 Проверка типов данных;\
#    1.3 Заполнение пропусков там, где это целесообразно и возможно;\
#    1.4 Проверка дубликатов;\
#    1.5 Проверка аномальных значений.
# 2. Задание необходимых функций;
# 3. Исследовательский анализ данных;
# 4. Рассчет показателей маркетинга;
# 5. Оценка окупаемости рекламы;
# 6. Общий вывод.

# %% [markdown]
# ## Обзор данных, поиск ошибок, предобработка

# %%
#импортируем необходимые бибилиотеки:
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta

# %%
#открываем файлы
try:
    visits = pd.read_csv(r"C:\Users\maste\OneDrive\Рабочий стол\Sprint 11 project\visits_info_short.csv")
    orders = pd.read_csv(r"C:\Users\maste\OneDrive\Рабочий стол\Sprint 11 project\orders_info_short.csv")
    costs = pd.read_csv(r"C:\Users\maste\OneDrive\Рабочий стол\Sprint 11 project\costs_info_short.csv")
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# ### Обзор данных

# %%
visits.head(10)
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %%
orders.head(10)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 5  129100331057  2019-05-01 01:56:28     4.99
# 6  626807144131  2019-05-01 02:39:21     4.99
# 7  914062168985  2019-05-01 02:02:18     4.99
# 8  769669137453  2019-05-01 03:39:47     4.99
# 9  434198630691  2019-05-01 18:16:50     5.99

# %%
costs.head(10)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Приведем заголовки столбцов в соответствие "правильному" стилю:

# %%
visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# %%
visits = visits.rename(
    columns={
        'user id':'user_id',
        'session start':'session_start',
        'session end':'session_end'
    }
)
visits.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
orders = orders.rename(
    columns={
        'user id':'user_id',
        'event dt':'event_dt'
    }
)
orders.head()
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
costs.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# **Вывод:**
# 1. Пропуски в данных отсутствуют;
# 2. Требуется проверка и обработка типов данных, содежащих дату и время;
# 3. Заголовки столбцов приведены к "правильному" стилю.

# %% [markdown]
# ### Проверка типов данных

# %% [markdown]
# По результатам обзора данных в п. 1.1 требуется преобразование типа данных в столбцах, содержащих дату и время.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# Проверим преобразования:

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %% [markdown]
# Вывод: Преобразования прошли успешно, необходимые типы данных изменены.

# %% [markdown]
# ### Работа с пропусками

# %% [markdown]
# В результате обзора в п 1.1 пропуски не обнаружены. Данные в корректировке не нуждаются.

# %% [markdown]
# ### Проверка дубликатов

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты не обнаружены. Проверим неявные дубликаты в названиях региона, устройств и каналов для тарблицы visits, а также название канало для таблицы costs.

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявные дубликаты не обнаружены.

# %% [markdown]
# ### Проверка аномальных значений

# %% [markdown]
# Проверим аномальные значения в столбцах, которые могут оказать влияние на результаты анализа:
# столбец revenue таблицы orders и столбец costs таблицы costs. Для проверки построим диаграмму размаха.

# %%
orders.boxplot('revenue', figsize=(5,5))
plt.show()
display(orders['revenue'].describe())
# Out:
# count    40212.000000
# mean         5.370608
# std          3.454208
# min          4.990000
# 25%          4.990000
# 50%          4.990000
# 75%          4.990000
# max         49.990000
# Name: revenue, dtype: float64

# %% [markdown]
# Видны еденичные случаи аномальных значений. Проверим как много таких значений.

# %%
orders.query('revenue > 20').count()
# Out:
# user_id     212
# event_dt    212
# revenue     212
# dtype: int64

# %% [markdown]
# 212 заказов имеют аномально высокие суммы заказа. Возможно, это самые преданные пользователи приложения.

# %%
costs.boxplot('costs', figsize=(5,5))
plt.show()
display(costs['costs'].describe())
# Out:
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %% [markdown]
# Значений выше 3го квартиля достаточно много, возможно это связано с увеличением рекламного бюджета.

# %% [markdown]
# ### Общий вывод по разделу

# %% [markdown]
# 1. Произведен обзор данных;
# 2. Данные, содержащие дату и время приведены к соответствующему типу;
# 3. Пропуски, явные и неявные дубликаты, а также аномалии, влиящие на результаты расчетов не обнаружены.

# %% [markdown]
# ## Задание необходимых функций

# %% [markdown]
# ### Функция для создания профилей пользователей:

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для подсчета Retention Rate:

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для подсчета конверсии:

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для подсчета LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания данных

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для построения графика Retention Rate

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для построения графика конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Общий вывод по разделу

# %% [markdown]
# Заданы все функции, необходимые в дальнейших расчетах.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профиль пользователей. Минимальная и максимальная дата привлечения пользователей

# %%
# определение профиля пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %%
# минимальная дата привлечения
min_date = profiles['first_ts'].min()
min_date
# Out:
# Timestamp('2019-05-01 00:00:41')

# %%
# максимальная дата привлечения
max_date = profiles['first_ts'].max()
max_date
# Out:
# Timestamp('2019-10-27 23:59:04')

# %% [markdown]
# Вывод:
# 1. Получена таблица профиля пользователей;
# 2. Минимальная дата привлечения: 01.05.2019
# 3. Максимальная дата привлечения: 27.10.2019

# %% [markdown]
# ### Регион пользователей. Доля платящих по региону

# %% [markdown]
# Выведем страны, из которых приходят пользователи:

# %%
profiles_region = profiles.groupby('region').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
profiles_region
# Out:
#                user_id
# region
# United States   100002
# UK               17575
# France           17450
# Germany          14981

# %% [markdown]
# Определим страну с наибольшим числом платящих пользователей:

# %%
profiles_region_payer = profiles.query('payer==True').groupby('region').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
profiles_region_payer
# Out:
#                user_id
# region
# United States     6902
# UK                 700
# France             663
# Germany            616

# %% [markdown]
# Определим долю платящих пользователей и добавим соответствуюй столбец в таблицу:

# %%
profiles_region['payer_part'] = profiles_region_payer['user_id']/profiles_region['user_id']
profiles_region
# Out:
#                user_id  payer_part
# region
# United States   100002    0.069019
# UK               17575    0.039829
# France           17450    0.037994
# Germany          14981    0.041119

# %% [markdown]
# Вывод:
# 1. Наибольшее число пользователей в США, следом идет Великобритания;
# 2. Наиболешее число платящих пользователей также в США, следом также идет Великобритания;
# 3. Наибольшая доля платящих пользователей в США, а на втором месте по доле платящих пользователей - Германия.

# %% [markdown]
# ### Устройства пользователей. Доля платящих по устройствам

# %% [markdown]
# Определим устройства, которые используют пользователи:

# %%
profiles_device = profiles.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
profiles_device
# Out:
#          user_id
# device
# iPhone     54479
# Android    35032
# PC         30455
# Mac        30042

# %% [markdown]
# Определим устройства с наибольшим числом платящих пользователей:

# %%
profiles_device_payer = profiles.query('payer==True').groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
profiles_device_payer
# Out:
#          user_id
# device
# iPhone      3382
# Android     2050
# Mac         1912
# PC          1537

# %% [markdown]
# Определим долю платящих пользователей и добавим соответствующий столбец в таблицу:

# %%
profiles_device['payer_part'] = profiles_device_payer['user_id']/profiles_device['user_id']
profiles_device
# Out:
#          user_id  payer_part
# device
# iPhone     54479    0.062079
# Android    35032    0.058518
# PC         30455    0.050468
# Mac        30042    0.063644

# %% [markdown]
# Вывод:
# 1. Большинство пользователей используют iPhone, на втором месте Android;
# 2. Большинство платящих пользователей также используют iPhone, на втором месте Android;
# 3. По доле платящих пользователей первое место у пользователей Mac, на втором месте iPhone.

# %% [markdown]
# ### Каналы привлечения пользователей. Доля платящих по каналам

# %% [markdown]
# Определим рекламные каналы, через которые приходят пользователи:

# %%
profiles_channel = profiles.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
profiles_channel
# Out:
#                     user_id
# channel
# organic               56439
# FaceBoom              29144
# TipTop                19561
# OppleCreativeMedia     8605
# LeapBob                8553
# WahooNetBanner         8553
# RocketSuperAds         4448
# MediaTornado           4364
# YRabbit                4312
# AdNonSense             3880
# lambdaMediaAds         2149

# %% [markdown]
# Определем рекламные каналы с наибольшим числом платящих пользователей:

# %%
profiles_channel_payer = profiles.query('payer==True').groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
profiles_channel_payer
# Out:
#                     user_id
# channel
# FaceBoom               3557
# TipTop                 1878
# organic                1160
# WahooNetBanner          453
# AdNonSense              440
# RocketSuperAds          352
# LeapBob                 262
# OppleCreativeMedia      233
# lambdaMediaAds          225
# YRabbit                 165
# MediaTornado            156

# %% [markdown]
# Определим долю платящих пользователей и добавим соответствующий столбец в таблицу:

# %%
profiles_channel['payer_part'] = profiles_channel_payer['user_id']/profiles_channel['user_id']
profiles_channel
# Out:
#                     user_id  payer_part
# channel
# organic               56439    0.020553
# FaceBoom              29144    0.122049
# TipTop                19561    0.096007
# OppleCreativeMedia     8605    0.027077
# LeapBob                8553    0.030633
# WahooNetBanner         8553    0.052964
# RocketSuperAds         4448    0.079137
# MediaTornado           4364    0.035747
# YRabbit                4312    0.038265
# AdNonSense             3880    0.113402
# lambdaMediaAds         2149    0.104700

# %% [markdown]
# Вывод:
# 1. Большая часть пользователей приходит по каналу organic, на втором месте FaceBoom;
# 2. Большая часть платящих пользователей приходит по каналу FaceBoom, на втором месте TipTop;
# 3. Наибольшая доля платящих пользователей у канала FaceBoom, следом идет AdNonSense.

# %% [markdown]
# ### Общий вывод по разделу

# %% [markdown]
# Даты привлечения пользователей:
# 1. Минимальная дата привлечения: 01.05.2019
# 2. Максимальная дата привлечения: 27.10.2019
#
# Страны пользователей:
# 1. Наибольшее число пользователей в США, следом идет Великобритания;
# 2. Наиболешее число платящих пользователей также в США, следом также идет Великобритания;
# 3. Наибольшая доля платящих пользователей в США, а на втором месте по доле платящих пользователей - Германия.
#
# Устройства пользователей:
# 1. Большинство пользователей используют iPhone, на втором месте Android;
# 2. Большинство платящих пользователей также используют iPhone, на втором месте Android;
# 3. По доле платящих пользователей первое место у пользователей Mac, на втором месте iPhone.
#
# Каналы привлечения пользователей:
# 1. Большая часть пользователей приходит по каналу organic, на втором месте FaceBoom;
# 2. Большая часть платящих пользователей приходит по каналу FaceBoom, на втором месте TipTop;
# 3. Наибольшая доля платящих пользователей у канала FaceBoom, следом идет AdNonSense.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Общая сумма расходов на маркетинг

# %%
total_cost = costs['costs'].sum()
total_cost
# Out:
# 105497.30000000002

# %% [markdown]
# Вывод: общая сумма затрат на рекламу составляет 105497.3

# %% [markdown]
# ### Распределение расходов по рекламным источникам

# %%
costs['dt'] = pd.to_datetime(costs['dt'])
costs_channel = costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False)
costs_channel
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# Вывод:
# Наибольшие расходы на рекламу в каналах TipTop и FaceBoom.

# %% [markdown]
# ### Визуализация динамики изменения расходов по времени

# %% [markdown]
# Построим графики изменения суммарной стоимости по времени и стоиомсти с разщбивкой по канала привлечения:

# %%
plt.figure(figsize=(15, 5))
ax1 = plt.subplot(1, 2, 1)
costs.pivot_table(
    index=['dt'], values='costs', aggfunc='sum'
).plot(grid=True, ax=ax1)
plt.ylabel('Сумма расходов')
plt.xlabel('Дата')
plt.title('Динамика изменения общих расходов на рекламу')

ax2 = plt.subplot(1, 2, 2, sharey = ax1)
costs.pivot_table(
    index=['dt'], columns='channel', values='costs', aggfunc='sum'
).plot(grid=True, ax=ax2)
plt.ylabel('Сумма расходов')
plt.xlabel('Дата')
plt.title('Динамика изменения расходов на рекламу по каналам')
plt.show()

# %% [markdown]
# Т.к. значения графика очень неоднородны и имеют много шумов для определения общей тенденции выполним "сглаживание" данных методом слозьщего среднего:

# %%
costs_sum = costs.pivot_table(index=['dt'], values='costs', aggfunc='sum')
channel_costs_sum = costs.pivot_table(index=['dt'], columns='channel', values='costs', aggfunc='sum')
window = 10
filter_data(costs_sum, window)
filter_data(channel_costs_sum, window)

plt.figure(figsize=(15, 5))
ax1 = plt.subplot(1, 2, 1)
costs_sum.plot(grid=True, ax=ax1)
plt.ylabel('Сумма расходов')
plt.xlabel('Дата')
plt.title('Динамика изменения общих расходов на рекламу')

ax2 = plt.subplot(1, 2, 2, sharey = ax1)
channel_costs_sum.plot(grid=True, ax=ax2)
plt.ylabel('Сумма расходов')
plt.xlabel('Дата')
plt.title('Динамика изменения расходов на рекламу по каналам')
plt.show()

# %% [markdown]
# Вывод:
# 1. Бюджет расходов на рекламу стабильно увеличивается и имеет скачкообразную структуру;
# 2. Увеличение рекламного бюжета происходит за счет каналов TipTop и FaceBoom, рекламные бюджеты остальных каналов относительно стабильны.

# %% [markdown]
# ### Средняя стоимость привлечения одного пользователя

# %%
profiles.groupby('channel')['acquisition_cost'].mean().sort_values(0, ascending=False)
# Out:
# C:\Users\maste\AppData\Local\Temp\ipykernel_8784\3410032950.py:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   profiles.groupby('channel')['acquisition_cost'].mean().sort_values(0, ascending=False)
# channel
# TipTop                2.799003
# FaceBoom              1.113286
# AdNonSense            1.008054
# lambdaMediaAds        0.724802
# WahooNetBanner        0.602245
# RocketSuperAds        0.412095
# OppleCreativeMedia    0.250000
# YRabbit               0.218975
# MediaTornado          0.218717
# LeapBob               0.210172
# organic               0.000000
# Name: acquisition_cost, dtype: float64

# %% [markdown]
# Вывод: Наибольшая средняя стоимость привлечения одного пользователя у каналов TipTop и FaceBoom.

# %% [markdown]
# ### Общий вывод по разделу

# %% [markdown]
# 1. Общая сумма затрат на рекламу составляет 105497.3;
# 2. Наибольшие расходы на рекламу в каналах TipTop и FaceBoom;
# 3. Бюджет расходов на рекламу стабильно увеличивается и имеет скачкообразную структуру;
# 4. Увеличение рекламного бюжета происходит за счет каналов TipTop и FaceBoom, рекламные бюджеты остальных каналов относительно стабильны;
# 5. Наибольшая средняя стоимость привлечения одного пользователя у каналов TipTop и FaceBoom.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# Установим момент и горизонт анализа данных. На календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи доллжны окупаться не позднее чем через две недели после привлечения.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа
profiles = profiles.query('channel != "organic"') # исключим пользователей, пришедших по каналу "organic"

# %% [markdown]
# ### Графики LTV и ROI, а также динамики LTV, CAC и ROI

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вывод:
# 1. Реклама в велом не окупается. ROI по истечению 14 дней не дотягивается до уровня окупаемости;
# 2. CAC не стабилен и увеличивается;
# 3. Динамика ROI на 14 день резко падает в июне, с середины июля пересекает уровнь окупаемости.

# %% [markdown]
# ### Конверсия и удержание, динамика их изменения

# %%
# смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вывод:
# 1. Конверсия пользователей имеет резкое увеличение в июне, но в дальнейшем имеет резкие скачки по показателям;
# 2. Динамика удержания платящих пользователей на 14 день относительно стабильна, динамика удержания неплатящих пользователей крайне низкая.

# %% [markdown]
# #### Конверсия и удержание с развибкой по устройствам

# %%
dimensions = ['device']
# смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# строим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вывод:
# 1. Конверсия пользователей устройства PC значительно ниже конверсии пользователей остальных устройств;
# 2. Удержание пользователей имеет колеебание, но в целом стабильно. Удержание пользователей на устройствах PC выше, чем на других устройствах.

# %% [markdown]
# #### Конверсия и удержание с разбивкой по регионам

# %%
dimensions = ['region']
# смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# строим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вывод:
# 1. Конверсия пользователей в США значительно выше, чем в других регионах. Динамика конверсии в июне выросла в США и резко упала в других регионах;
# 2. Удержание платящих пользователей в США ниже, чем в других регионах.

# %% [markdown]
# #### Конверсия и удержание с разбивкой по каналам привлечения

# %%
dimensions = ['channel']
# смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# строим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вывод:
# 1. Конверсия каналов FaceBoom, AdNonSense, LambdaMediaAds и TipTop находится на достотаточно высоком уровне;
# 2. При этом удержание пользователей каналов FaceBoom, AdNonSense крайне низкое.

# %% [markdown]
# ### Графики LTV и ROI, а также динамики LTV, CAC и ROI с разбивкой по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=10
)

# %% [markdown]
# Вывод:
# 1. С конца июня наблюдается резкий рост динамики стоиомсти привлечения, особенно для устройств iPhone и Mac;
# 2. Пользователи PC стабильно окупаются, чего нельзя сказать об остальных устройствах;
# 3. Динамика ROI на 14 день в целом выше уровня окупаести только на устройствах PC, возможно есть технические проблемы на других устройствах.

# %% [markdown]
# ### Графики LTV и ROI, а также динамики LTV, CAC и ROI с разбивкой по регионам

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Вывод:
# 1. С конца июня наблюдается резкий рост динамики стоимости привлечения в США. В других регионах наоборот произошло снижение стоимости привлечения;
# 2. Пользователи в Германии, Франции, Великобритании стабильно окупаются. Не окупаются пользователи в США.
# 3. Можем предположить что проблема характерна только для одного региона - США.

# %% [markdown]
# ### Графики LTV и ROI, а также динамики LTV, CAC и ROI с разбивкой по каналам

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Вывод:
# 1. С конца июня наблюдается резкий рост динамики стоимости по каналу привлечения TipTop. Динамика стоимости привлечения по другим каналам относительно стабильна;
# 2. Реклама по каналам ADNonSense, FaceBoom, TipTop не окупается, по остальным каналам окупается.

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# **Исключим пользователей США и проверим окупаемость, в том числе с разделением по устройствам и каналам в других странах:**

# %%
profiles_without_usa = profiles.query('region != "United States"')

# %%
# Окупаемость в целом
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_without_usa, orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вывод:
# ВО Франции, Германии и Великобритании реклама окупается.

# %%
# Окупаемость с разбивкой по устройствам
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_without_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=10
)

# %% [markdown]
# Вывод:\
# Во Франции, Германии и Великобритании окупается пользователи всех устройств.

# %%
# Окупаемость с разбивкой по каналам привлечения
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_without_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Вывод:\
# Во Франции, Германии и Великобритании окупаются все каналы привлечения кроме ADNonSense.

# %% [markdown]
# **Оставим только пользователей в США и проверим окупаемость по устройствам и каналам привлечения:**

# %%
profiles_usa = profiles.query('region == "United States"')

# %%
# Окупаемость в целом
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вывод:
# В США реклама не окупается

# %%
# Окупаемость с разбивкой по устройствам
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=10
)

# %% [markdown]
# Вывод:\
# В США не окупаются пользователи всех устройств.

# %%
# Окупаемость с разбивкой по каналам привлечения
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Вывод:\
# В США окупаются все каналы привлечения пользователей кроме FaceBoom и TipTop.

# %% [markdown]
# ### Общий вывод по разделу

# %% [markdown]
# **Общая окупаемость:**
#
# Реклама в целом не окупается. При этом окупается реклама в Германии, Франции, Великобритании и не окупается в США, что оказывает существенное влияние на общий результат ввиду большого кол-ва пользователей в данном регионе;
#
# **Конверсия и удержание:**
# 1. Конверсия пользователей имеет резкое увеличение в июне, в дальнейшем имеет резкие, но стабильные скачки по показателям;
# 2. Динамика удержания платящих пользователей на 14 день имеет резкие скачки, как и конверсия, но относительно стабильна, динамика удержания неплатящих пользователей крайне низкая.
#
# **Конверсия и удержание по устройствам:**
# 1. Конверсия пользователей устройства PC значительно ниже конверсии пользователей остальных устройств;
# 2. Удержание пользователей имеет колебания, но в целом стабильно. Удержание пользователей на устройствах PC выше, чем на других устройствах.
#
# **Конверсия и удержание по регионам:**
# 1. Конверсия пользователей в США значительно выше, чем в других регионах. Динамика конверсии в июне выросла в США и резко упала в других регионах;
# 2. Удержание платящих пользователей в США ниже, чем в других регионах.
#
# **Конверсия и удержание по каналам привлечения:**
# 1. Конверсия каналов FaceBoom, AdNonSense, LambdaMediaAds и TipTop находится на достотаточно высоком уровне;
# 2. При этом удержание пользователей каналов FaceBoom, AdNonSense крайне низкое.
#
# **Окупаемость по устройствам:**
# 1. С конца июня наблюдается резкий рост динамики стоимости привлечения, особенно для устройств iPhone и Mac;
# 2. Пользователи PC стабильно окупаются, чего нельзя сказать об остальных устройствах;
# 3. Во Франции, Германии и Великобритании окупается пользователи всех устройств, однако, в США не окупаются пользователи всех устройств.
# Проблемные устройства: iPhone и Mac
#
# **Окупаемость по регионам:**
# 1. С конца июня наблюдается резкий рост динамики стоимости привлечения в США. В других регионах наоборот произошло снижение стоимости привлечения;
# 2. Пользователи в Германии, Франции, Великобритании стабильно окупаются. Не окупаются пользователи в США.
# Проблемный регион: США
#
# **Окупаемость по каналам привлечения:**
# 1. С конца июня наблюдается резкий рост динамики стоимости по каналу привлечения TipTop. Динамика стоимости привлечения по другим каналам относительно стабильна или снижается;
# 2. Реклама по каналам ADNonSense, FaceBoom, TipTop не окупается, по остальным каналам окупается
# Проблемные каналы: ADNonSense, FaceBoom, TipTop
#
# **Возможные причины обнаруженных проблем:**
# 1. Возможны какие-то технические проблемы в США для пользователей всех устройств. Возможно вышла новая версия или какое-то обновление;
# 2. Резкий рост и слишком большой рекламный бюджет в США по каналу TipTop. Стабильно высокие рекламные бюджеты по каналам ADNonSense, FaceBoom;
# 3. Каналы FaceBoom, TipTop, AdNonSense привлекают некачественную (нецелевую) аудиторию.
#
# **Предварительные рекомендации для рекламного отдела:**
# 1. Проверить логи для устройств в США на предмет ошибок и технических проблем;
# 2. Скорректировать рекламные бюджеты по каналам ADNonSense, FaceBoom, TipTop;
# 3. Проверить рекламные материалы и целевую аудиторию каналов FaceBoom, TipTop, AdNonSense.

# %% [markdown]
# ## Общий вывод по исследованию

# %% [markdown]
# **Портрет пользователей:**\
# Страны пользователей:
# 1. Наибольшее число пользователей в США, следом идет Великобритания;
# 2. Наибольшее число платящих пользователей также в США, следом также идет Великобритания;
# 3. Наибольшая доля платящих пользователей в США, а на втором месте по доле платящих пользователей - Германия.
#
# Устройства пользователей:
# 1. Большинство пользователей используют iPhone, на втором месте Android;
# 2. Большинство платящих пользователей также используют iPhone, на втором месте Android;
# 3. По доле платящих пользователей первое место у пользователей Mac, на втором месте iPhone.
#
# Каналы привлечения пользователей:
# 1. Большая часть пользователей приходит по каналу organic, на втором месте FaceBoom;
# 2. Большая часть платящих пользователей приходит по каналу FaceBoom, на втором месте TipTop;
# 3. Наибольшая доля платящих пользователей у канала FaceBoom, следом идет AdNonSense.
#
# **Оценка окупаемости:**
#
# Реклама в целом не окупается. При этом окупается реклама в Германии, Франции, Великобритании и не окупается в США, что оказывает существенное влияние на общий результат ввиду большого кол-ва пользователей в данном регионе;
#
# Конверсия и удержание:
# 1. Конверсия пользователей имеет резкое увеличение в июне, в дальнейшем имеет резкие, но стабильные скачки по показателям;
# 2. Динамика удержания платящих пользователей на 14 день имеет резкие скачки, как и конверсия, но относительно стабильна, динамика удержания неплатящих пользователей крайне низкая.
#
# Конверсия и удержание по устройствам:
# 1. Конверсия пользователей устройства PC значительно ниже конверсии пользователей остальных устройств;
# 2. Удержание пользователей имеет колебания, но в целом стабильно. Удержание пользователей на устройствах PC выше, чем на других устройствах.
#
# Конверсия и удержание по регионам:
# 1. Конверсия пользователей в США значительно выше, чем в других регионах. Динамика конверсии в июне выросла в США и резко упала в других регионах;
# 2. Удержание платящих пользователей в США ниже, чем в других регионах.
#
# Конверсия и удержание по каналам привлечения:
# 1. Конверсия каналов FaceBoom, AdNonSense, LambdaMediaAds и TipTop находится на достотаточно высоком уровне;
# 2. При этом удержание пользователей каналов FaceBoom, AdNonSense крайне низкое.
#
# Окупаемость по устройствам:
# 1. С конца июня наблюдается резкий рост динамики стоимости привлечения, особенно для устройств iPhone и Mac;
# 2. Пользователи Android и PC стабильно окупаются, чего нельзя сказать о пользователях iPhone и Mac;
# 3. Во Франции, Германии и Великобритании окупается пользователи всех устройств, в США не окупаются пользователи всех устройств.
# Проблемные устройства: iPhone и Mac
#
# Окупаемость по регионам:
# 1. С конца июня наблюдается резкий рост динамики стоимости привлечения в США. В других регионах рост есть, но не такой значительный;
# 2. Пользователи в Германии, Франции, Великобритании стабильно окупаются. Не окупаются пользователи в США.
# Проблемный регион: США
#
# Окупаемость по каналам привлечения:
# 1. С конца июня наблюдается резкий рост динамики стоимости по каналу привлечения TipTop. Динамика стоимости привлечения по другим каналам относительно стабильна;
# 2. Реклама по каналам ADNonSense, FaceBoom, TipTop не окупается, по остальным каналам окупается
# Проблемные каналы: ADNonSense, FaceBoom, TipTop
#
# **Возможные причины обнаруженных проблем:**
# 1. Возможны какие-то технические проблемы в США для пользователей всех устройств. Возможно вышла новая версия или какое-то обновление;
# 2. Резкий рост и слишком большой рекламный бюджет в США по каналу TipTop. Стабильно высокие рекламные бюджеты по каналам ADNonSense, FaceBoom;
# 3. Каналы FaceBoom, TipTop, AdNonSense привлекают некачественную (нецелевую) аудиторию.
#
# **Рекомендации для отдела маркетинга:**
# 1. Проверить логи для устройств в США на предмет ошибок и технических проблем;
# 2. Скорректировать рекламные бюджеты по каналам ADNonSense, FaceBoom, TipTop;
# 3. Проверить рекламные материалы и целевую аудиторию каналов FaceBoom, TipTop, AdNonSense.
